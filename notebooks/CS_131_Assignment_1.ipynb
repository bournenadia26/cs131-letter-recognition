# %% [markdown]
# # Instructions
#
# * Make a copy of this colab.
# * Add code where needed.
# * Execute all cells, save colab with output.
# * Submit your .ipynb file to canvas

# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

# %% [markdown]
# ## Problem 1 - IsPalindrome - 15 points
#
#
# Write a function to check if a given string is a palindrome and test it on the given input.

# %%
def IsPalindrome(s: str) -> bool:
  # translated prev java code for this (comments are notes for myself)

  # create version of given string without spaces, caps, & special characters
  simpler_str = ""
  for char in s:
    if char.isalnum(): # 'is alphanumeric', char.isLetterOrDigit()
      simpler_str += char.lower() # char.toLowerCase()

  # compare string head and tail
  left, right = 0, len(simpler_str)-1 # python lets you stack variable assignments
  while left < right:
    if simpler_str[left] != simpler_str[right]: # str[idx] is like str.charAt(idx)
      return False
    left += 1
    right -= 1

  return True

# %%
# DO NOT MODIFY THIS CELL, BUT DO EXECUTE THIS CELL

a = ['', 'a', 'aa', 'abba', 'abab', 'abca']
expected = [True, True, True, True, False, False]

for ix, s in enumerate(a):
  b = IsPalindrome(s)
  print(s, '->IsPalindrom->', b)
  assert b == expected[ix]
# Out:
#  ->IsPalindrom-> True
# a ->IsPalindrom-> True
# aa ->IsPalindrom-> True
# abba ->IsPalindrom-> True
# abab ->IsPalindrom-> False
# abca ->IsPalindrom-> False

# %% [markdown]
# # Problem 2 - FlipSort - 20 points
#
# Use the function `FlipPrefix()` given below that can flip a prefix an array to sort the array in increasing order. You can compare array elements but the only way to modify the array is to use `FlipPrefix()`. You may want to use NumPy's `argmax()` function.

# %%
# DO NOT MODIFY THIS CELL, BUT DO EXECUTE THIS CELL

def FlipPrefix(a: list[int], before_n: int) -> list[int]:
  assert 0 < before_n <= len(a)
  b = a[:before_n]
  return b[::-1] + a[before_n:]

# %%
def FlipSort(a: list[int]) -> list[int]:
  # FlipPrefix takes a given list and flips the contents up to a given idx(exclusive)
  # np.argmax() returns the idx of max val in list

  for i in range(len(a), 1, -1): # for (int i = a.length; i > 1 [until 1]; i--)
    max_idx = np.argmax(a[:i:]) # list[start(inclusive) , stop(exclusive), step(increment)]
    a = FlipPrefix(a, max_idx+1)
    # max elem is at front now
    a = FlipPrefix(a, i)
    # flip entire segment up till i so max is at the end
    # range gets shrunk. repeat.
  return a

# %%
# DO NOT MODIFY THIS CELL, BUT DO EXECUTE THIS CELL

a = [[3, 1, 2, 5, 4],
     [1],
     [100, 101, 51, 41, 31, 21, 11, 1]]

for row in a:
  b = FlipSort(row)
  print(row, '->FlipSort->', b)
  assert b == sorted(row)
# Out:
# [3, 1, 2, 5, 4] ->FlipSort-> [1, 2, 3, 4, 5]
# [1] ->FlipSort-> [1]
# [100, 101, 51, 41, 31, 21, 11, 1] ->FlipSort-> [1, 11, 21, 31, 41, 51, 100, 101]

# %% [markdown]
# # Problem 3 - Plot - 15 point
#
# Plot following 4 functions in a 2x2 subplots using `plt.subplot()` function.
#
# 1.   y = x
# 1.   y = x^2
# 1.   y = x^3
# 1.   y = sigmoid(x)

# %%
x = np.linspace(-2, 2, 30)
plt.subplot(2, 2, 1)
plt.plot(x, x)
# Update code here

# x^2
plt.subplot(2, 2, 2)
plt.plot(x, np.square(x))

# x^3
plt.subplot(2, 2, 3)
plt.plot(x, np.power(x, 3))

# sigmoid(x)
plt.subplot(2, 2, 4)
plt.plot(x, 1 / (1 + np.exp(-x))) # google def

plt.show()

# %% [markdown]
# # Problem 4 - Implement Multiple Linear Regression from scratch - 50 points
#
# ## Overview
#
# In this problem, you will implement a **Multiple Linear Regression (MLR) model from scratch** (without bias) for a **Soundscape Emotion Recognition System**.
#
# ## Dataset:
#
# The dataset consists of:
#
# *   `arousal`: This is the ground truth (correct answer)
# *   **Other columns**: The rest of the columns are features to use to train MLR model
#
# You will use `test.csv` as the test set. **Do not modify this file**, as it will be used to compare the loss score across all students.
#
# Additionally, you must **split** `train.csv` **into training and validation sets** in a **90:10 ratio**. No further data processing is required.
#
# No further data processing is needed.
#
# ## Implementation details:
#
# *   Train and test the MLR model using the provided datasets: `Train.csv` and `Test.csv` (available on Canvas). These files contain pre-extracted and processed features from audio clips.
# *   Treat the `arousal` column as the **target variable** (in ML coding convension, this is called `y`), and all other columns as **input features** (in ML coding convension, this is called `X`)
# *   **Do not perform any additional data processing** on the dataset.
# *   Use **Stochastic Gradient Descent (SGD)** as the optimization algorithm.
# *   You should experiment with different **learning rates** and **number of training epochs** to minimize loss.
# *   While it is common to initialize the weight vector randomly, in this homework we require you to set it to the 0 vector.
# *   Plot the loss curve for both training and validation in a single graph (you can use `mathplotlib` or `seaborn` libraries for this)
# *   **Important:** you **CANNOT** use any machine learning libraries or packages like `sklearn` or `tensorflow` for this implementation. However, you may use `numpy` and/or `pandas` if needed.
#
# ## Submission Requirements:
#
# *   Make a copy of this colab, add your code, run all the cells, and save output. Submit your completed code as .ipynb file with output. Don't submit a link to your colab.
# *   Your submission must:
#   *   Successfully train the model and display test results.
#   *   Avoid runtime errors—points will be deducted for models that do not run correctly.
#   *   Clearly present the train, validation, and test loss, along with a loss curve plot for both training and validation.
# *   If your model fails to complete training, you will not receive full credit.

# %%
from sklearn.model_selection import train_test_split

# load, shuffle, split df
train_n_val_df = pd.read_csv("https://raw.githubusercontent.com/bournenadia26/cs131/refs/heads/main/train.csv")
test_df = pd.read_csv("https://raw.githubusercontent.com/bournenadia26/cs131/refs/heads/main/test.csv")

train_n_val_df = train_n_val_df.sample(frac=1).reset_index(drop=True)

train_df, val_df = train_test_split(train_n_val_df, test_size=0.1, random_state=1)

# convert to arrs for mathing
X_train = train_df.drop(columns=['arousal']).to_numpy()
y_train = train_df['arousal'].to_numpy()
X_val = val_df.drop(columns=['arousal']).to_numpy()
y_val = val_df['arousal'].to_numpy()
X_test = test_df.drop(columns=['arousal']).to_numpy()
y_test = test_df['arousal'].to_numpy()

# params
eta = 0.0000000001  # learning rate
num_of_epochs = 500
w = np.zeros(X_train.shape[1])  # initialize weights to zero vector (fixes matrix multp. errs)
test_loss_mean = 0

# store loss for graphs
training_loss_data = []
val_loss_data = []

for epoch in range(num_of_epochs):
  training_epoch_loss = []
  val_epoch_loss = []

  # TRAINING SET
  for i in range(X_train.shape[0]): #for every row in X_train, run step 2,3,4,5

    # step 2: compute prediction (for this row i)
    y_hat_train = np.dot(X_train[i],w)

    # step 3: calculate loss (for this row i)
    train_loss = ((y_train[i] - y_hat_train) ** 2)

    # step 4: compute gradient (for this row i)
    gradient = -2 * X_train[i] * (y_train[i] - y_hat_train)

    # step 5: update weight (for this row i)
    w = w - (eta * gradient)

    # store losses (for this row i)
    training_epoch_loss.append(train_loss)

  # VALIDATION SET
  for j in range(X_val.shape[0]):
    y_hat_val = np.dot(X_val[j],w) # step 2
    val_loss = np.mean((y_val[j] - y_hat_val) ** 2) # step 3
    val_epoch_loss.append(val_loss) # store losses for this row j

  # store mean losses for graph
  training_loss_data.append(np.mean(training_epoch_loss))
  val_loss_data.append(np.mean(val_epoch_loss))

  print(f"Average losses for Epoch {epoch+1}:")
  print(f"Training loss = {np.mean(training_epoch_loss):.4f}, Validation loss = {np.mean(val_epoch_loss):.4f}\n")

# TEST SET
y_hat_test = np.dot(X_test, w)
test_loss_avg = np.mean((y_test - y_hat_test) ** 2)
print("------------------------------------------------")
print(f"\nAvg Test Loss: {test_loss_avg}\n")
print("-----------------------------------------------\n")

# Plot training vs validation loss
plt.plot(range(1, len(training_loss_data) + 1), training_loss_data, label="Training Loss")
plt.plot(range(1, len(val_loss_data) + 1), val_loss_data, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.show()
# Out:
# Average losses for Epoch 1:
# Training loss = 0.3930, Validation loss = 0.3846
#
# Average losses for Epoch 2:
# Training loss = 0.3672, Validation loss = 0.3622
#
# Average losses for Epoch 3:
# Training loss = 0.3541, Validation loss = 0.3509
#
# Average losses for Epoch 4:
# Training loss = 0.3464, Validation loss = 0.3441
#
# Average losses for Epoch 5:
# Training loss = 0.3410, Validation loss = 0.3390
#
# Average losses for Epoch 6:
# Training loss = 0.3367, Validation loss = 0.3347
#
# Average losses for Epoch 7:
# Training loss = 0.3330, Validation loss = 0.3308
#
# Average losses for Epoch 8:
# Training loss = 0.3296, Validation loss = 0.3271
#
# Average losses for Epoch 9:
# Training loss = 0.3266, Validation loss = 0.3235
#
# Average losses for Epoch 10:
# Training loss = 0.3237, Validation loss = 0.3200
#
# Average losses for Epoch 11:
# Training loss = 0.3210, Validation loss = 0.3167
#
# Average losses for Epoch 12:
# Training loss = 0.3185, Validation loss = 0.3136
#
# Average losses for Epoch 13:
# Training loss = 0.3161, Validation loss = 0.3106
#
# Average losses for Epoch 14:
# Training loss = 0.3138, Validation loss = 0.3078
#
# Average losses for Epoch 15:
# Training loss = 0.3117, Validation loss = 0.3052
#
# Average losses for Epoch 16:
# Training loss = 0.3096, Validation loss = 0.3026
#
# Average losses for Epoch 17:
# Training loss = 0.3077, Validation loss = 0.3002
#
# Average losses for Epoch 18:
# Training loss = 0.3058, Validation loss = 0.2980
#
# Average losses for Epoch 19:
# Training loss = 0.3040, Validation loss = 0.2958
#
# Average losses for Epoch 20:
# Training loss = 0.3023, Validation loss = 0.2938
#
# Average losses for Epoch 21:
# Training loss = 0.3007, Validation loss = 0.2919
#
# Average losses for Epoch 22:
# Training loss = 0.2992, Validation loss = 0.2901
#
# Average losses for Epoch 23:
# Training loss = 0.2977, Validation loss = 0.2884
#
# Average losses for Epoch 24:
# Training loss = 0.2963, Validation loss = 0.2867
#
# Average losses for Epoch 25:
# Training loss = 0.2949, Validation loss = 0.2852
#
# Average losses for Epoch 26:
# Training loss = 0.2936, Validation loss = 0.2837
#
# Average losses for Epoch 27:
# Training loss = 0.2923, Validation loss = 0.2823
#
# Average losses for Epoch 28:
# Training loss = 0.2911, Validation loss = 0.2809
#
# Average losses for Epoch 29:
# Training loss = 0.2899, Validation loss = 0.2796
#
# Average losses for Epoch 30:
# Training loss = 0.2887, Validation loss = 0.2784
#
# Average losses for Epoch 31:
# Training loss = 0.2876, Validation loss = 0.2772
#
# Average losses for Epoch 32:
# Training loss = 0.2866, Validation loss = 0.2761
#
# Average losses for Epoch 33:
# Training loss = 0.2855, Validation loss = 0.2750
#
# Average losses for Epoch 34:
# Training loss = 0.2845, Validation loss = 0.2740
#
# Average losses for Epoch 35:
# Training loss = 0.2835, Validation loss = 0.2730
#
# Average losses for Epoch 36:
# Training loss = 0.2826, Validation loss = 0.2721
#
# Average losses for Epoch 37:
# Training loss = 0.2817, Validation loss = 0.2712
#
# Average losses for Epoch 38:
# Training loss = 0.2808, Validation loss = 0.2703
#
# Average losses for Epoch 39:
# Training loss = 0.2799, Validation loss = 0.2695
#
# Average losses for Epoch 40:
# Training loss = 0.2791, Validation loss = 0.2687
#
# Average losses for Epoch 41:
# Training loss = 0.2782, Validation loss = 0.2679
#
# Average losses for Epoch 42:
# Training loss = 0.2774, Validation loss = 0.2672
#
# Average losses for Epoch 43:
# Training loss = 0.2767, Validation loss = 0.2665
#
# Average losses for Epoch 44:
# Training loss = 0.2759, Validation loss = 0.2658
#
# Average losses for Epoch 45:
# Training loss = 0.2751, Validation loss = 0.2651
#
# Average losses for Epoch 46:
# Training loss = 0.2744, Validation loss = 0.2645
#
# Average losses for Epoch 47:
# Training loss = 0.2737, Validation loss = 0.2638
#
# Average losses for Epoch 48:
# Training loss = 0.2730, Validation loss = 0.2632
#
# Average losses for Epoch 49:
# Training loss = 0.2723, Validation loss = 0.2627
#
# Average losses for Epoch 50:
# Training loss = 0.2717, Validation loss = 0.2621
#
# Average losses for Epoch 51:
# Training loss = 0.2710, Validation loss = 0.2616
#
# Average losses for Epoch 52:
# Training loss = 0.2704, Validation loss = 0.2610
#
# Average losses for Epoch 53:
# Training loss = 0.2698, Validation loss = 0.2605
#
# Average losses for Epoch 54:
# Training loss = 0.2692, Validation loss = 0.2601
#
# Average losses for Epoch 55:
# Training loss = 0.2686, Validation loss = 0.2596
#
# Average losses for Epoch 56:
# Training loss = 0.2680, Validation loss = 0.2591
#
# Average losses for Epoch 57:
# Training loss = 0.2674, Validation loss = 0.2587
#
# Average losses for Epoch 58:
# Training loss = 0.2669, Validation loss = 0.2582
#
# Average losses for Epoch 59:
# Training loss = 0.2663, Validation loss = 0.2578
#
# Average losses for Epoch 60:
# Training loss = 0.2658, Validation loss = 0.2574
#
# Average losses for Epoch 61:
# Training loss = 0.2653, Validation loss = 0.2570
#
# Average losses for Epoch 62:
# Training loss = 0.2648, Validation loss = 0.2566
#
# Average losses for Epoch 63:
# Training loss = 0.2643, Validation loss = 0.2563
#
# Average losses for Epoch 64:
# Training loss = 0.2638, Validation loss = 0.2559
#
# Average losses for Epoch 65:
# Training loss = 0.2633, Validation loss = 0.2555
#
# Average losses for Epoch 66:
# Training loss = 0.2628, Validation loss = 0.2552
#
# Average losses for Epoch 67:
# Training loss = 0.2624, Validation loss = 0.2549
#
# Average losses for Epoch 68:
# Training loss = 0.2619, Validation loss = 0.2545
#
# Average losses for Epoch 69:
# Training loss = 0.2615, Validation loss = 0.2542
#
# Average losses for Epoch 70:
# Training loss = 0.2610, Validation loss = 0.2539
#
# Average losses for Epoch 71:
# Training loss = 0.2606, Validation loss = 0.2536
#
# Average losses for Epoch 72:
# Training loss = 0.2602, Validation loss = 0.2533
#
# Average losses for Epoch 73:
# Training loss = 0.2598, Validation loss = 0.2530
#
# Average losses for Epoch 74:
# Training loss = 0.2594, Validation loss = 0.2528
#
# Average losses for Epoch 75:
# Training loss = 0.2590, Validation loss = 0.2525
#
# Average losses for Epoch 76:
# Training loss = 0.2586, Validation loss = 0.2522
#
# Average losses for Epoch 77:
# Training loss = 0.2582, Validation loss = 0.2520
#
# Average losses for Epoch 78:
# Training loss = 0.2578, Validation loss = 0.2517
#
# Average losses for Epoch 79:
# Training loss = 0.2574, Validation loss = 0.2515
#
# Average losses for Epoch 80:
# Training loss = 0.2571, Validation loss = 0.2512
#
# Average losses for Epoch 81:
# Training loss = 0.2567, Validation loss = 0.2510
#
# Average losses for Epoch 82:
# Training loss = 0.2564, Validation loss = 0.2508
#
# Average losses for Epoch 83:
# Training loss = 0.2560, Validation loss = 0.2505
#
# Average losses for Epoch 84:
# Training loss = 0.2557, Validation loss = 0.2503
#
# Average losses for Epoch 85:
# Training loss = 0.2553, Validation loss = 0.2501
#
# Average losses for Epoch 86:
# Training loss = 0.2550, Validation loss = 0.2499
#
# Average losses for Epoch 87:
# Training loss = 0.2547, Validation loss = 0.2497
#
# Average losses for Epoch 88:
# Training loss = 0.2544, Validation loss = 0.2495
#
# Average losses for Epoch 89:
# Training loss = 0.2540, Validation loss = 0.2493
#
# Average losses for Epoch 90:
# Training loss = 0.2537, Validation loss = 0.2491
#
# Average losses for Epoch 91:
# Training loss = 0.2534, Validation loss = 0.2489
#
# Average losses for Epoch 92:
# Training loss = 0.2531, Validation loss = 0.2488
#
# Average losses for Epoch 93:
# Training loss = 0.2528, Validation loss = 0.2486
#
# Average losses for Epoch 94:
# Training loss = 0.2526, Validation loss = 0.2484
#
# Average losses for Epoch 95:
# Training loss = 0.2523, Validation loss = 0.2482
#
# Average losses for Epoch 96:
# Training loss = 0.2520, Validation loss = 0.2481
#
# Average losses for Epoch 97:
# Training loss = 0.2517, Validation loss = 0.2479
#
# Average losses for Epoch 98:
# Training loss = 0.2515, Validation loss = 0.2478
#
# Average losses for Epoch 99:
# Training loss = 0.2512, Validation loss = 0.2476
#
# Average losses for Epoch 100:
# Training loss = 0.2509, Validation loss = 0.2475
#
# Average losses for Epoch 101:
# Training loss = 0.2507, Validation loss = 0.2473
#
# Average losses for Epoch 102:
# Training loss = 0.2504, Validation loss = 0.2472
#
# Average losses for Epoch 103:
# Training loss = 0.2502, Validation loss = 0.2470
#
# Average losses for Epoch 104:
# Training loss = 0.2499, Validation loss = 0.2469
#
# Average losses for Epoch 105:
# Training loss = 0.2497, Validation loss = 0.2468
#
# Average losses for Epoch 106:
# Training loss = 0.2494, Validation loss = 0.2466
#
# Average losses for Epoch 107:
# Training loss = 0.2492, Validation loss = 0.2465
#
# Average losses for Epoch 108:
# Training loss = 0.2490, Validation loss = 0.2464
#
# Average losses for Epoch 109:
# Training loss = 0.2487, Validation loss = 0.2462
#
# Average losses for Epoch 110:
# Training loss = 0.2485, Validation loss = 0.2461
#
# Average losses for Epoch 111:
# Training loss = 0.2483, Validation loss = 0.2460
#
# Average losses for Epoch 112:
# Training loss = 0.2481, Validation loss = 0.2459
#
# Average losses for Epoch 113:
# Training loss = 0.2479, Validation loss = 0.2458
#
# Average losses for Epoch 114:
# Training loss = 0.2476, Validation loss = 0.2457
#
# Average losses for Epoch 115:
# Training loss = 0.2474, Validation loss = 0.2456
#
# Average losses for Epoch 116:
# Training loss = 0.2472, Validation loss = 0.2454
#
# Average losses for Epoch 117:
# Training loss = 0.2470, Validation loss = 0.2453
#
# Average losses for Epoch 118:
# Training loss = 0.2468, Validation loss = 0.2452
#
# Average losses for Epoch 119:
# Training loss = 0.2466, Validation loss = 0.2451
#
# Average losses for Epoch 120:
# Training loss = 0.2464, Validation loss = 0.2450
#
# Average losses for Epoch 121:
# Training loss = 0.2462, Validation loss = 0.2449
#
# Average losses for Epoch 122:
# Training loss = 0.2461, Validation loss = 0.2448
#
# Average losses for Epoch 123:
# Training loss = 0.2459, Validation loss = 0.2448
#
# Average losses for Epoch 124:
# Training loss = 0.2457, Validation loss = 0.2447
#
# Average losses for Epoch 125:
# Training loss = 0.2455, Validation loss = 0.2446
#
# Average losses for Epoch 126:
# Training loss = 0.2453, Validation loss = 0.2445
#
# Average losses for Epoch 127:
# Training loss = 0.2451, Validation loss = 0.2444
#
# Average losses for Epoch 128:
# Training loss = 0.2450, Validation loss = 0.2443
#
# Average losses for Epoch 129:
# Training loss = 0.2448, Validation loss = 0.2442
#
# Average losses for Epoch 130:
# Training loss = 0.2446, Validation loss = 0.2442
#
# Average losses for Epoch 131:
# Training loss = 0.2445, Validation loss = 0.2441
#
# Average losses for Epoch 132:
# Training loss = 0.2443, Validation loss = 0.2440
#
# Average losses for Epoch 133:
# Training loss = 0.2441, Validation loss = 0.2439
#
# Average losses for Epoch 134:
# Training loss = 0.2440, Validation loss = 0.2438
#
# Average losses for Epoch 135:
# Training loss = 0.2438, Validation loss = 0.2438
#
# Average losses for Epoch 136:
# Training loss = 0.2437, Validation loss = 0.2437
#
# Average losses for Epoch 137:
# Training loss = 0.2435, Validation loss = 0.2436
#
# Average losses for Epoch 138:
# Training loss = 0.2433, Validation loss = 0.2436
#
# Average losses for Epoch 139:
# Training loss = 0.2432, Validation loss = 0.2435
#
# Average losses for Epoch 140:
# Training loss = 0.2430, Validation loss = 0.2434
#
# Average losses for Epoch 141:
# Training loss = 0.2429, Validation loss = 0.2434
#
# Average losses for Epoch 142:
# Training loss = 0.2428, Validation loss = 0.2433
#
# Average losses for Epoch 143:
# Training loss = 0.2426, Validation loss = 0.2432
#
# Average losses for Epoch 144:
# Training loss = 0.2425, Validation loss = 0.2432
#
# Average losses for Epoch 145:
# Training loss = 0.2423, Validation loss = 0.2431
#
# Average losses for Epoch 146:
# Training loss = 0.2422, Validation loss = 0.2431
#
# Average losses for Epoch 147:
# Training loss = 0.2420, Validation loss = 0.2430
#
# Average losses for Epoch 148:
# Training loss = 0.2419, Validation loss = 0.2429
#
# Average losses for Epoch 149:
# Training loss = 0.2418, Validation loss = 0.2429
#
# Average losses for Epoch 150:
# Training loss = 0.2416, Validation loss = 0.2428
#
# Average losses for Epoch 151:
# Training loss = 0.2415, Validation loss = 0.2428
#
# Average losses for Epoch 152:
# Training loss = 0.2414, Validation loss = 0.2427
#
# Average losses for Epoch 153:
# Training loss = 0.2413, Validation loss = 0.2427
#
# Average losses for Epoch 154:
# Training loss = 0.2411, Validation loss = 0.2426
#
# Average losses for Epoch 155:
# Training loss = 0.2410, Validation loss = 0.2426
#
# Average losses for Epoch 156:
# Training loss = 0.2409, Validation loss = 0.2425
#
# Average losses for Epoch 157:
# Training loss = 0.2408, Validation loss = 0.2425
#
# Average losses for Epoch 158:
# Training loss = 0.2406, Validation loss = 0.2424
#
# Average losses for Epoch 159:
# Training loss = 0.2405, Validation loss = 0.2424
#
# Average losses for Epoch 160:
# Training loss = 0.2404, Validation loss = 0.2423
#
# Average losses for Epoch 161:
# Training loss = 0.2403, Validation loss = 0.2423
#
# Average losses for Epoch 162:
# Training loss = 0.2402, Validation loss = 0.2423
#
# Average losses for Epoch 163:
# Training loss = 0.2401, Validation loss = 0.2422
#
# Average losses for Epoch 164:
# Training loss = 0.2399, Validation loss = 0.2422
#
# Average losses for Epoch 165:
# Training loss = 0.2398, Validation loss = 0.2421
#
# Average losses for Epoch 166:
# Training loss = 0.2397, Validation loss = 0.2421
#
# Average losses for Epoch 167:
# Training loss = 0.2396, Validation loss = 0.2420
#
# Average losses for Epoch 168:
# Training loss = 0.2395, Validation loss = 0.2420
#
# Average losses for Epoch 169:
# Training loss = 0.2394, Validation loss = 0.2420
#
# Average losses for Epoch 170:
# Training loss = 0.2393, Validation loss = 0.2419
#
# Average losses for Epoch 171:
# Training loss = 0.2392, Validation loss = 0.2419
#
# Average losses for Epoch 172:
# Training loss = 0.2391, Validation loss = 0.2419
#
# Average losses for Epoch 173:
# Training loss = 0.2390, Validation loss = 0.2418
#
# Average losses for Epoch 174:
# Training loss = 0.2389, Validation loss = 0.2418
#
# Average losses for Epoch 175:
# Training loss = 0.2388, Validation loss = 0.2418
#
# Average losses for Epoch 176:
# Training loss = 0.2387, Validation loss = 0.2417
#
# Average losses for Epoch 177:
# Training loss = 0.2386, Validation loss = 0.2417
#
# Average losses for Epoch 178:
# Training loss = 0.2385, Validation loss = 0.2417
#
# Average losses for Epoch 179:
# Training loss = 0.2384, Validation loss = 0.2416
#
# Average losses for Epoch 180:
# Training loss = 0.2383, Validation loss = 0.2416
#
# Average losses for Epoch 181:
# Training loss = 0.2382, Validation loss = 0.2416
#
# Average losses for Epoch 182:
# Training loss = 0.2381, Validation loss = 0.2415
#
# Average losses for Epoch 183:
# Training loss = 0.2380, Validation loss = 0.2415
#
# Average losses for Epoch 184:
# Training loss = 0.2379, Validation loss = 0.2415
#
# Average losses for Epoch 185:
# Training loss = 0.2378, Validation loss = 0.2414
#
# Average losses for Epoch 186:
# Training loss = 0.2377, Validation loss = 0.2414
#
# Average losses for Epoch 187:
# Training loss = 0.2376, Validation loss = 0.2414
#
# Average losses for Epoch 188:
# Training loss = 0.2375, Validation loss = 0.2414
#
# Average losses for Epoch 189:
# Training loss = 0.2374, Validation loss = 0.2413
#
# Average losses for Epoch 190:
# Training loss = 0.2374, Validation loss = 0.2413
#
# Average losses for Epoch 191:
# Training loss = 0.2373, Validation loss = 0.2413
#
# Average losses for Epoch 192:
# Training loss = 0.2372, Validation loss = 0.2413
#
# Average losses for Epoch 193:
# Training loss = 0.2371, Validation loss = 0.2412
#
# Average losses for Epoch 194:
# Training loss = 0.2370, Validation loss = 0.2412
#
# Average losses for Epoch 195:
# Training loss = 0.2369, Validation loss = 0.2412
#
# Average losses for Epoch 196:
# Training loss = 0.2368, Validation loss = 0.2412
#
# Average losses for Epoch 197:
# Training loss = 0.2368, Validation loss = 0.2411
#
# Average losses for Epoch 198:
# Training loss = 0.2367, Validation loss = 0.2411
#
# Average losses for Epoch 199:
# Training loss = 0.2366, Validation loss = 0.2411
#
# Average losses for Epoch 200:
# Training loss = 0.2365, Validation loss = 0.2411
#
# Average losses for Epoch 201:
# Training loss = 0.2364, Validation loss = 0.2410
#
# Average losses for Epoch 202:
# Training loss = 0.2364, Validation loss = 0.2410
#
# Average losses for Epoch 203:
# Training loss = 0.2363, Validation loss = 0.2410
#
# Average losses for Epoch 204:
# Training loss = 0.2362, Validation loss = 0.2410
#
# Average losses for Epoch 205:
# Training loss = 0.2361, Validation loss = 0.2409
#
# Average losses for Epoch 206:
# Training loss = 0.2360, Validation loss = 0.2409
#
# Average losses for Epoch 207:
# Training loss = 0.2360, Validation loss = 0.2409
#
# Average losses for Epoch 208:
# Training loss = 0.2359, Validation loss = 0.2409
#
# Average losses for Epoch 209:
# Training loss = 0.2358, Validation loss = 0.2409
#
# Average losses for Epoch 210:
# Training loss = 0.2357, Validation loss = 0.2408
#
# Average losses for Epoch 211:
# Training loss = 0.2357, Validation loss = 0.2408
#
# Average losses for Epoch 212:
# Training loss = 0.2356, Validation loss = 0.2408
#
# Average losses for Epoch 213:
# Training loss = 0.2355, Validation loss = 0.2408
#
# Average losses for Epoch 214:
# Training loss = 0.2354, Validation loss = 0.2408
#
# Average losses for Epoch 215:
# Training loss = 0.2354, Validation loss = 0.2408
#
# Average losses for Epoch 216:
# Training loss = 0.2353, Validation loss = 0.2407
#
# Average losses for Epoch 217:
# Training loss = 0.2352, Validation loss = 0.2407
#
# Average losses for Epoch 218:
# Training loss = 0.2352, Validation loss = 0.2407
#
# Average losses for Epoch 219:
# Training loss = 0.2351, Validation loss = 0.2407
#
# Average losses for Epoch 220:
# Training loss = 0.2350, Validation loss = 0.2407
#
# Average losses for Epoch 221:
# Training loss = 0.2349, Validation loss = 0.2406
#
# Average losses for Epoch 222:
# Training loss = 0.2349, Validation loss = 0.2406
#
# Average losses for Epoch 223:
# Training loss = 0.2348, Validation loss = 0.2406
#
# Average losses for Epoch 224:
# Training loss = 0.2347, Validation loss = 0.2406
#
# Average losses for Epoch 225:
# Training loss = 0.2347, Validation loss = 0.2406
#
# Average losses for Epoch 226:
# Training loss = 0.2346, Validation loss = 0.2406
#
# Average losses for Epoch 227:
# Training loss = 0.2345, Validation loss = 0.2405
#
# Average losses for Epoch 228:
# Training loss = 0.2345, Validation loss = 0.2405
#
# Average losses for Epoch 229:
# Training loss = 0.2344, Validation loss = 0.2405
#
# Average losses for Epoch 230:
# Training loss = 0.2343, Validation loss = 0.2405
#
# Average losses for Epoch 231:
# Training loss = 0.2343, Validation loss = 0.2405
#
# Average losses for Epoch 232:
# Training loss = 0.2342, Validation loss = 0.2405
#
# Average losses for Epoch 233:
# Training loss = 0.2341, Validation loss = 0.2405
#
# Average losses for Epoch 234:
# Training loss = 0.2341, Validation loss = 0.2404
#
# Average losses for Epoch 235:
# Training loss = 0.2340, Validation loss = 0.2404
#
# Average losses for Epoch 236:
# Training loss = 0.2340, Validation loss = 0.2404
#
# Average losses for Epoch 237:
# Training loss = 0.2339, Validation loss = 0.2404
#
# Average losses for Epoch 238:
# Training loss = 0.2338, Validation loss = 0.2404
#
# Average losses for Epoch 239:
# Training loss = 0.2338, Validation loss = 0.2404
#
# Average losses for Epoch 240:
# Training loss = 0.2337, Validation loss = 0.2404
#
# Average losses for Epoch 241:
# Training loss = 0.2336, Validation loss = 0.2403
#
# Average losses for Epoch 242:
# Training loss = 0.2336, Validation loss = 0.2403
#
# Average losses for Epoch 243:
# Training loss = 0.2335, Validation loss = 0.2403
#
# Average losses for Epoch 244:
# Training loss = 0.2335, Validation loss = 0.2403
#
# Average losses for Epoch 245:
# Training loss = 0.2334, Validation loss = 0.2403
#
# Average losses for Epoch 246:
# Training loss = 0.2333, Validation loss = 0.2403
#
# Average losses for Epoch 247:
# Training loss = 0.2333, Validation loss = 0.2403
#
# Average losses for Epoch 248:
# Training loss = 0.2332, Validation loss = 0.2402
#
# Average losses for Epoch 249:
# Training loss = 0.2332, Validation loss = 0.2402
#
# Average losses for Epoch 250:
# Training loss = 0.2331, Validation loss = 0.2402
#
# Average losses for Epoch 251:
# Training loss = 0.2330, Validation loss = 0.2402
#
# Average losses for Epoch 252:
# Training loss = 0.2330, Validation loss = 0.2402
#
# Average losses for Epoch 253:
# Training loss = 0.2329, Validation loss = 0.2402
#
# Average losses for Epoch 254:
# Training loss = 0.2329, Validation loss = 0.2402
#
# Average losses for Epoch 255:
# Training loss = 0.2328, Validation loss = 0.2402
#
# Average losses for Epoch 256:
# Training loss = 0.2328, Validation loss = 0.2401
#
# Average losses for Epoch 257:
# Training loss = 0.2327, Validation loss = 0.2401
#
# Average losses for Epoch 258:
# Training loss = 0.2326, Validation loss = 0.2401
#
# Average losses for Epoch 259:
# Training loss = 0.2326, Validation loss = 0.2401
#
# Average losses for Epoch 260:
# Training loss = 0.2325, Validation loss = 0.2401
#
# Average losses for Epoch 261:
# Training loss = 0.2325, Validation loss = 0.2401
#
# Average losses for Epoch 262:
# Training loss = 0.2324, Validation loss = 0.2401
#
# Average losses for Epoch 263:
# Training loss = 0.2324, Validation loss = 0.2401
#
# Average losses for Epoch 264:
# Training loss = 0.2323, Validation loss = 0.2400
#
# Average losses for Epoch 265:
# Training loss = 0.2323, Validation loss = 0.2400
#
# Average losses for Epoch 266:
# Training loss = 0.2322, Validation loss = 0.2400
#
# Average losses for Epoch 267:
# Training loss = 0.2321, Validation loss = 0.2400
#
# Average losses for Epoch 268:
# Training loss = 0.2321, Validation loss = 0.2400
#
# Average losses for Epoch 269:
# Training loss = 0.2320, Validation loss = 0.2400
#
# Average losses for Epoch 270:
# Training loss = 0.2320, Validation loss = 0.2400
#
# Average losses for Epoch 271:
# Training loss = 0.2319, Validation loss = 0.2400
#
# Average losses for Epoch 272:
# Training loss = 0.2319, Validation loss = 0.2399
#
# Average losses for Epoch 273:
# Training loss = 0.2318, Validation loss = 0.2399
#
# Average losses for Epoch 274:
# Training loss = 0.2318, Validation loss = 0.2399
#
# Average losses for Epoch 275:
# Training loss = 0.2317, Validation loss = 0.2399
#
# Average losses for Epoch 276:
# Training loss = 0.2317, Validation loss = 0.2399
#
# Average losses for Epoch 277:
# Training loss = 0.2316, Validation loss = 0.2399
#
# Average losses for Epoch 278:
# Training loss = 0.2316, Validation loss = 0.2399
#
# Average losses for Epoch 279:
# Training loss = 0.2315, Validation loss = 0.2399
#
# Average losses for Epoch 280:
# Training loss = 0.2315, Validation loss = 0.2399
#
# Average losses for Epoch 281:
# Training loss = 0.2314, Validation loss = 0.2398
#
# Average losses for Epoch 282:
# Training loss = 0.2314, Validation loss = 0.2398
#
# Average losses for Epoch 283:
# Training loss = 0.2313, Validation loss = 0.2398
#
# Average losses for Epoch 284:
# Training loss = 0.2313, Validation loss = 0.2398
#
# Average losses for Epoch 285:
# Training loss = 0.2312, Validation loss = 0.2398
#
# Average losses for Epoch 286:
# Training loss = 0.2312, Validation loss = 0.2398
#
# Average losses for Epoch 287:
# Training loss = 0.2311, Validation loss = 0.2398
#
# Average losses for Epoch 288:
# Training loss = 0.2311, Validation loss = 0.2398
#
# Average losses for Epoch 289:
# Training loss = 0.2310, Validation loss = 0.2397
#
# Average losses for Epoch 290:
# Training loss = 0.2310, Validation loss = 0.2397
#
# Average losses for Epoch 291:
# Training loss = 0.2309, Validation loss = 0.2397
#
# Average losses for Epoch 292:
# Training loss = 0.2309, Validation loss = 0.2397
#
# Average losses for Epoch 293:
# Training loss = 0.2308, Validation loss = 0.2397
#
# Average losses for Epoch 294:
# Training loss = 0.2308, Validation loss = 0.2397
#
# Average losses for Epoch 295:
# Training loss = 0.2307, Validation loss = 0.2397
#
# Average losses for Epoch 296:
# Training loss = 0.2307, Validation loss = 0.2397
#
# Average losses for Epoch 297:
# Training loss = 0.2306, Validation loss = 0.2397
#
# Average losses for Epoch 298:
# Training loss = 0.2306, Validation loss = 0.2396
#
# Average losses for Epoch 299:
# Training loss = 0.2305, Validation loss = 0.2396
#
# Average losses for Epoch 300:
# Training loss = 0.2305, Validation loss = 0.2396
#
# Average losses for Epoch 301:
# Training loss = 0.2304, Validation loss = 0.2396
#
# Average losses for Epoch 302:
# Training loss = 0.2304, Validation loss = 0.2396
#
# Average losses for Epoch 303:
# Training loss = 0.2303, Validation loss = 0.2396
#
# Average losses for Epoch 304:
# Training loss = 0.2303, Validation loss = 0.2396
#
# Average losses for Epoch 305:
# Training loss = 0.2302, Validation loss = 0.2396
#
# Average losses for Epoch 306:
# Training loss = 0.2302, Validation loss = 0.2396
#
# Average losses for Epoch 307:
# Training loss = 0.2301, Validation loss = 0.2395
#
# Average losses for Epoch 308:
# Training loss = 0.2301, Validation loss = 0.2395
#
# Average losses for Epoch 309:
# Training loss = 0.2300, Validation loss = 0.2395
#
# Average losses for Epoch 310:
# Training loss = 0.2300, Validation loss = 0.2395
#
# Average losses for Epoch 311:
# Training loss = 0.2299, Validation loss = 0.2395
#
# Average losses for Epoch 312:
# Training loss = 0.2299, Validation loss = 0.2395
#
# Average losses for Epoch 313:
# Training loss = 0.2298, Validation loss = 0.2395
#
# Average losses for Epoch 314:
# Training loss = 0.2298, Validation loss = 0.2395
#
# Average losses for Epoch 315:
# Training loss = 0.2298, Validation loss = 0.2395
#
# Average losses for Epoch 316:
# Training loss = 0.2297, Validation loss = 0.2394
#
# Average losses for Epoch 317:
# Training loss = 0.2297, Validation loss = 0.2394
#
# Average losses for Epoch 318:
# Training loss = 0.2296, Validation loss = 0.2394
#
# Average losses for Epoch 319:
# Training loss = 0.2296, Validation loss = 0.2394
#
# Average losses for Epoch 320:
# Training loss = 0.2295, Validation loss = 0.2394
#
# Average losses for Epoch 321:
# Training loss = 0.2295, Validation loss = 0.2394
#
# Average losses for Epoch 322:
# Training loss = 0.2294, Validation loss = 0.2394
#
# Average losses for Epoch 323:
# Training loss = 0.2294, Validation loss = 0.2394
#
# Average losses for Epoch 324:
# Training loss = 0.2293, Validation loss = 0.2393
#
# Average losses for Epoch 325:
# Training loss = 0.2293, Validation loss = 0.2393
#
# Average losses for Epoch 326:
# Training loss = 0.2293, Validation loss = 0.2393
#
# Average losses for Epoch 327:
# Training loss = 0.2292, Validation loss = 0.2393
#
# Average losses for Epoch 328:
# Training loss = 0.2292, Validation loss = 0.2393
#
# Average losses for Epoch 329:
# Training loss = 0.2291, Validation loss = 0.2393
#
# Average losses for Epoch 330:
# Training loss = 0.2291, Validation loss = 0.2393
#
# Average losses for Epoch 331:
# Training loss = 0.2290, Validation loss = 0.2393
#
# Average losses for Epoch 332:
# Training loss = 0.2290, Validation loss = 0.2393
#
# Average losses for Epoch 333:
# Training loss = 0.2289, Validation loss = 0.2392
#
# Average losses for Epoch 334:
# Training loss = 0.2289, Validation loss = 0.2392
#
# Average losses for Epoch 335:
# Training loss = 0.2289, Validation loss = 0.2392
#
# Average losses for Epoch 336:
# Training loss = 0.2288, Validation loss = 0.2392
#
# Average losses for Epoch 337:
# Training loss = 0.2288, Validation loss = 0.2392
#
# Average losses for Epoch 338:
# Training loss = 0.2287, Validation loss = 0.2392
#
# Average losses for Epoch 339:
# Training loss = 0.2287, Validation loss = 0.2392
#
# Average losses for Epoch 340:
# Training loss = 0.2286, Validation loss = 0.2392
#
# Average losses for Epoch 341:
# Training loss = 0.2286, Validation loss = 0.2391
#
# Average losses for Epoch 342:
# Training loss = 0.2285, Validation loss = 0.2391
#
# Average losses for Epoch 343:
# Training loss = 0.2285, Validation loss = 0.2391
#
# Average losses for Epoch 344:
# Training loss = 0.2285, Validation loss = 0.2391
#
# Average losses for Epoch 345:
# Training loss = 0.2284, Validation loss = 0.2391
#
# Average losses for Epoch 346:
# Training loss = 0.2284, Validation loss = 0.2391
#
# Average losses for Epoch 347:
# Training loss = 0.2283, Validation loss = 0.2391
#
# Average losses for Epoch 348:
# Training loss = 0.2283, Validation loss = 0.2391
#
# Average losses for Epoch 349:
# Training loss = 0.2282, Validation loss = 0.2390
#
# Average losses for Epoch 350:
# Training loss = 0.2282, Validation loss = 0.2390
#
# Average losses for Epoch 351:
# Training loss = 0.2282, Validation loss = 0.2390
#
# Average losses for Epoch 352:
# Training loss = 0.2281, Validation loss = 0.2390
#
# Average losses for Epoch 353:
# Training loss = 0.2281, Validation loss = 0.2390
#
# Average losses for Epoch 354:
# Training loss = 0.2280, Validation loss = 0.2390
#
# Average losses for Epoch 355:
# Training loss = 0.2280, Validation loss = 0.2390
#
# Average losses for Epoch 356:
# Training loss = 0.2279, Validation loss = 0.2390
#
# Average losses for Epoch 357:
# Training loss = 0.2279, Validation loss = 0.2389
#
# Average losses for Epoch 358:
# Training loss = 0.2279, Validation loss = 0.2389
#
# Average losses for Epoch 359:
# Training loss = 0.2278, Validation loss = 0.2389
#
# Average losses for Epoch 360:
# Training loss = 0.2278, Validation loss = 0.2389
#
# Average losses for Epoch 361:
# Training loss = 0.2277, Validation loss = 0.2389
#
# Average losses for Epoch 362:
# Training loss = 0.2277, Validation loss = 0.2389
#
# Average losses for Epoch 363:
# Training loss = 0.2277, Validation loss = 0.2389
#
# Average losses for Epoch 364:
# Training loss = 0.2276, Validation loss = 0.2389
#
# Average losses for Epoch 365:
# Training loss = 0.2276, Validation loss = 0.2388
#
# Average losses for Epoch 366:
# Training loss = 0.2275, Validation loss = 0.2388
#
# Average losses for Epoch 367:
# Training loss = 0.2275, Validation loss = 0.2388
#
# Average losses for Epoch 368:
# Training loss = 0.2274, Validation loss = 0.2388
#
# Average losses for Epoch 369:
# Training loss = 0.2274, Validation loss = 0.2388
#
# Average losses for Epoch 370:
# Training loss = 0.2274, Validation loss = 0.2388
#
# Average losses for Epoch 371:
# Training loss = 0.2273, Validation loss = 0.2388
#
# Average losses for Epoch 372:
# Training loss = 0.2273, Validation loss = 0.2388
#
# Average losses for Epoch 373:
# Training loss = 0.2272, Validation loss = 0.2387
#
# Average losses for Epoch 374:
# Training loss = 0.2272, Validation loss = 0.2387
#
# Average losses for Epoch 375:
# Training loss = 0.2272, Validation loss = 0.2387
#
# Average losses for Epoch 376:
# Training loss = 0.2271, Validation loss = 0.2387
#
# Average losses for Epoch 377:
# Training loss = 0.2271, Validation loss = 0.2387
#
# Average losses for Epoch 378:
# Training loss = 0.2270, Validation loss = 0.2387
#
# Average losses for Epoch 379:
# Training loss = 0.2270, Validation loss = 0.2387
#
# Average losses for Epoch 380:
# Training loss = 0.2270, Validation loss = 0.2387
#
# Average losses for Epoch 381:
# Training loss = 0.2269, Validation loss = 0.2386
#
# Average losses for Epoch 382:
# Training loss = 0.2269, Validation loss = 0.2386
#
# Average losses for Epoch 383:
# Training loss = 0.2268, Validation loss = 0.2386
#
# Average losses for Epoch 384:
# Training loss = 0.2268, Validation loss = 0.2386
#
# Average losses for Epoch 385:
# Training loss = 0.2267, Validation loss = 0.2386
#
# Average losses for Epoch 386:
# Training loss = 0.2267, Validation loss = 0.2386
#
# Average losses for Epoch 387:
# Training loss = 0.2267, Validation loss = 0.2386
#
# Average losses for Epoch 388:
# Training loss = 0.2266, Validation loss = 0.2385
#
# Average losses for Epoch 389:
# Training loss = 0.2266, Validation loss = 0.2385
#
# Average losses for Epoch 390:
# Training loss = 0.2265, Validation loss = 0.2385
#
# Average losses for Epoch 391:
# Training loss = 0.2265, Validation loss = 0.2385
#
# Average losses for Epoch 392:
# Training loss = 0.2265, Validation loss = 0.2385
#
# Average losses for Epoch 393:
# Training loss = 0.2264, Validation loss = 0.2385
#
# Average losses for Epoch 394:
# Training loss = 0.2264, Validation loss = 0.2385
#
# Average losses for Epoch 395:
# Training loss = 0.2263, Validation loss = 0.2384
#
# Average losses for Epoch 396:
# Training loss = 0.2263, Validation loss = 0.2384
#
# Average losses for Epoch 397:
# Training loss = 0.2263, Validation loss = 0.2384
#
# Average losses for Epoch 398:
# Training loss = 0.2262, Validation loss = 0.2384
#
# Average losses for Epoch 399:
# Training loss = 0.2262, Validation loss = 0.2384
#
# Average losses for Epoch 400:
# Training loss = 0.2261, Validation loss = 0.2384
#
# Average losses for Epoch 401:
# Training loss = 0.2261, Validation loss = 0.2384
#
# Average losses for Epoch 402:
# Training loss = 0.2261, Validation loss = 0.2384
#
# Average losses for Epoch 403:
# Training loss = 0.2260, Validation loss = 0.2383
#
# Average losses for Epoch 404:
# Training loss = 0.2260, Validation loss = 0.2383
#
# Average losses for Epoch 405:
# Training loss = 0.2259, Validation loss = 0.2383
#
# Average losses for Epoch 406:
# Training loss = 0.2259, Validation loss = 0.2383
#
# Average losses for Epoch 407:
# Training loss = 0.2259, Validation loss = 0.2383
#
# Average losses for Epoch 408:
# Training loss = 0.2258, Validation loss = 0.2383
#
# Average losses for Epoch 409:
# Training loss = 0.2258, Validation loss = 0.2383
#
# Average losses for Epoch 410:
# Training loss = 0.2257, Validation loss = 0.2382
#
# Average losses for Epoch 411:
# Training loss = 0.2257, Validation loss = 0.2382
#
# Average losses for Epoch 412:
# Training loss = 0.2257, Validation loss = 0.2382
#
# Average losses for Epoch 413:
# Training loss = 0.2256, Validation loss = 0.2382
#
# Average losses for Epoch 414:
# Training loss = 0.2256, Validation loss = 0.2382
#
# Average losses for Epoch 415:
# Training loss = 0.2256, Validation loss = 0.2382
#
# Average losses for Epoch 416:
# Training loss = 0.2255, Validation loss = 0.2382
#
# Average losses for Epoch 417:
# Training loss = 0.2255, Validation loss = 0.2381
#
# Average losses for Epoch 418:
# Training loss = 0.2254, Validation loss = 0.2381
#
# Average losses for Epoch 419:
# Training loss = 0.2254, Validation loss = 0.2381
#
# Average losses for Epoch 420:
# Training loss = 0.2254, Validation loss = 0.2381
#
# Average losses for Epoch 421:
# Training loss = 0.2253, Validation loss = 0.2381
#
# Average losses for Epoch 422:
# Training loss = 0.2253, Validation loss = 0.2381
#
# Average losses for Epoch 423:
# Training loss = 0.2252, Validation loss = 0.2381
#
# Average losses for Epoch 424:
# Training loss = 0.2252, Validation loss = 0.2380
#
# Average losses for Epoch 425:
# Training loss = 0.2252, Validation loss = 0.2380
#
# Average losses for Epoch 426:
# Training loss = 0.2251, Validation loss = 0.2380
#
# Average losses for Epoch 427:
# Training loss = 0.2251, Validation loss = 0.2380
#
# Average losses for Epoch 428:
# Training loss = 0.2250, Validation loss = 0.2380
#
# Average losses for Epoch 429:
# Training loss = 0.2250, Validation loss = 0.2380
#
# Average losses for Epoch 430:
# Training loss = 0.2250, Validation loss = 0.2379
#
# Average losses for Epoch 431:
# Training loss = 0.2249, Validation loss = 0.2379
#
# Average losses for Epoch 432:
# Training loss = 0.2249, Validation loss = 0.2379
#
# Average losses for Epoch 433:
# Training loss = 0.2249, Validation loss = 0.2379
#
# Average losses for Epoch 434:
# Training loss = 0.2248, Validation loss = 0.2379
#
# Average losses for Epoch 435:
# Training loss = 0.2248, Validation loss = 0.2379
#
# Average losses for Epoch 436:
# Training loss = 0.2247, Validation loss = 0.2379
#
# Average losses for Epoch 437:
# Training loss = 0.2247, Validation loss = 0.2378
#
# Average losses for Epoch 438:
# Training loss = 0.2247, Validation loss = 0.2378
#
# Average losses for Epoch 439:
# Training loss = 0.2246, Validation loss = 0.2378
#
# Average losses for Epoch 440:
# Training loss = 0.2246, Validation loss = 0.2378
#
# Average losses for Epoch 441:
# Training loss = 0.2245, Validation loss = 0.2378
#
# Average losses for Epoch 442:
# Training loss = 0.2245, Validation loss = 0.2378
#
# Average losses for Epoch 443:
# Training loss = 0.2245, Validation loss = 0.2378
#
# Average losses for Epoch 444:
# Training loss = 0.2244, Validation loss = 0.2377
#
# Average losses for Epoch 445:
# Training loss = 0.2244, Validation loss = 0.2377
#
# Average losses for Epoch 446:
# Training loss = 0.2244, Validation loss = 0.2377
#
# Average losses for Epoch 447:
# Training loss = 0.2243, Validation loss = 0.2377
#
# Average losses for Epoch 448:
# Training loss = 0.2243, Validation loss = 0.2377
#
# Average losses for Epoch 449:
# Training loss = 0.2242, Validation loss = 0.2377
#
# Average losses for Epoch 450:
# Training loss = 0.2242, Validation loss = 0.2376
#
# Average losses for Epoch 451:
# Training loss = 0.2242, Validation loss = 0.2376
#
# Average losses for Epoch 452:
# Training loss = 0.2241, Validation loss = 0.2376
#
# Average losses for Epoch 453:
# Training loss = 0.2241, Validation loss = 0.2376
#
# Average losses for Epoch 454:
# Training loss = 0.2241, Validation loss = 0.2376
#
# Average losses for Epoch 455:
# Training loss = 0.2240, Validation loss = 0.2376
#
# Average losses for Epoch 456:
# Training loss = 0.2240, Validation loss = 0.2376
#
# Average losses for Epoch 457:
# Training loss = 0.2239, Validation loss = 0.2375
#
# Average losses for Epoch 458:
# Training loss = 0.2239, Validation loss = 0.2375
#
# Average losses for Epoch 459:
# Training loss = 0.2239, Validation loss = 0.2375
#
# Average losses for Epoch 460:
# Training loss = 0.2238, Validation loss = 0.2375
#
# Average losses for Epoch 461:
# Training loss = 0.2238, Validation loss = 0.2375
#
# Average losses for Epoch 462:
# Training loss = 0.2238, Validation loss = 0.2375
#
# Average losses for Epoch 463:
# Training loss = 0.2237, Validation loss = 0.2374
#
# Average losses for Epoch 464:
# Training loss = 0.2237, Validation loss = 0.2374
#
# Average losses for Epoch 465:
# Training loss = 0.2236, Validation loss = 0.2374
#
# Average losses for Epoch 466:
# Training loss = 0.2236, Validation loss = 0.2374
#
# Average losses for Epoch 467:
# Training loss = 0.2236, Validation loss = 0.2374
#
# Average losses for Epoch 468:
# Training loss = 0.2235, Validation loss = 0.2374
#
# Average losses for Epoch 469:
# Training loss = 0.2235, Validation loss = 0.2373
#
# Average losses for Epoch 470:
# Training loss = 0.2235, Validation loss = 0.2373
#
# Average losses for Epoch 471:
# Training loss = 0.2234, Validation loss = 0.2373
#
# Average losses for Epoch 472:
# Training loss = 0.2234, Validation loss = 0.2373
#
# Average losses for Epoch 473:
# Training loss = 0.2233, Validation loss = 0.2373
#
# Average losses for Epoch 474:
# Training loss = 0.2233, Validation loss = 0.2373
#
# Average losses for Epoch 475:
# Training loss = 0.2233, Validation loss = 0.2373
#
# Average losses for Epoch 476:
# Training loss = 0.2232, Validation loss = 0.2372
#
# Average losses for Epoch 477:
# Training loss = 0.2232, Validation loss = 0.2372
#
# Average losses for Epoch 478:
# Training loss = 0.2232, Validation loss = 0.2372
#
# Average losses for Epoch 479:
# Training loss = 0.2231, Validation loss = 0.2372
#
# Average losses for Epoch 480:
# Training loss = 0.2231, Validation loss = 0.2372
#
# Average losses for Epoch 481:
# Training loss = 0.2230, Validation loss = 0.2372
#
# Average losses for Epoch 482:
# Training loss = 0.2230, Validation loss = 0.2371
#
# Average losses for Epoch 483:
# Training loss = 0.2230, Validation loss = 0.2371
#
# Average losses for Epoch 484:
# Training loss = 0.2229, Validation loss = 0.2371
#
# Average losses for Epoch 485:
# Training loss = 0.2229, Validation loss = 0.2371
#
# Average losses for Epoch 486:
# Training loss = 0.2229, Validation loss = 0.2371
#
# Average losses for Epoch 487:
# Training loss = 0.2228, Validation loss = 0.2371
#
# Average losses for Epoch 488:
# Training loss = 0.2228, Validation loss = 0.2370
#
# Average losses for Epoch 489:
# Training loss = 0.2227, Validation loss = 0.2370
#
# Average losses for Epoch 490:
# Training loss = 0.2227, Validation loss = 0.2370
#
# Average losses for Epoch 491:
# Training loss = 0.2227, Validation loss = 0.2370
#
# Average losses for Epoch 492:
# Training loss = 0.2226, Validation loss = 0.2370
#
# Average losses for Epoch 493:
# Training loss = 0.2226, Validation loss = 0.2370
#
# Average losses for Epoch 494:
# Training loss = 0.2226, Validation loss = 0.2369
#
# Average losses for Epoch 495:
# Training loss = 0.2225, Validation loss = 0.2369
#
# Average losses for Epoch 496:
# Training loss = 0.2225, Validation loss = 0.2369
#
# Average losses for Epoch 497:
# Training loss = 0.2225, Validation loss = 0.2369
#
# Average losses for Epoch 498:
# Training loss = 0.2224, Validation loss = 0.2369
#
# Average losses for Epoch 499:
# Training loss = 0.2224, Validation loss = 0.2369
#
# Average losses for Epoch 500:
# Training loss = 0.2223, Validation loss = 0.2368
#
# ------------------------------------------------
#
# Avg Test Loss: 0.17423597640317973
#
# -----------------------------------------------
